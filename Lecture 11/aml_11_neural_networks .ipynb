# %% [markdown]
# <center><img src="img/aml-logo.png" width="600"/>
#
# ***
#
# <center>Lecture 11</center>
#
# ***
#
# <center>Neural Networks </center>
#
# ***
#
# <center>26 April 2022<center>
# <center>Rahman Peimankar<center>

# %% [markdown]
# # Agenda
#
# * Basic Architecture
# * Inside The Neural Networks
# * sklearn implementation

# %% [markdown]
# # History
# * Nearly everything we talk about today existed ~1990
# * What changed?
#     1. More data
#     2. Faster computers (GPUs)
#     3. Some improvements:

# %% [markdown]
# # Logistic Regression as Neural Net

# %% [markdown]
# <div>
# <center>
# <img src="img/Qimage-2.JPG" width="400"/>
# </div>

# %% [markdown]
# # Basic Architecture

# %% [markdown]
# <div>
# <center>
# <img src="img/Qimage-3.JPG" width="1000"/>
# </div>

# %% [markdown]
# # Quiz 1
#
# In a Multilayer neural network, which of the three nodes is responsible for the calculations and has no interaction with the outside world?
#
# A) Input node
#
# B) Hidden node
#
# C) Output node
#
# Please answer here:
#
# https://PollEv.com/multiple_choice_polls/TwT5WeJU2jqAOBN5bRW8Q/respond

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# **Artificial neuron**
# <img src="img/Qimage-4.png" width="630"/>
#
# </td>
# <td>
#
# **Non-linearity problem**
# <img src="img/Qimage-5.png" width="400"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>

# %% [markdown]
# <center>
#
# <img src="img/Qimage-6.png" width="900"/>
# </div>

# %% [markdown]
# # Inside The Neural Networks (NNs)!

# %% [markdown]
# * Usually, people call Neural Networks a **black box** because it is hard to understand what they are doing.
# * We are going to break down each components of the **black box** and walking through how they work together.

# %% [markdown]
# Today,
#
# * we will talk about what and how NNs do things.
# * we will also talk about how NNs are fit to data with **Backpropagation**.
# * we will in addition learn about variations of NNs, including **Deep Learning**.

# %% [markdown]
# # Problem Definition

# %% [markdown]
# * Let's imagine that we have tested a drug that was designed to treat an illness.
# * We gave the drug to **3** different group of people with **3** different **Dosages**; low, medium, and high.

# %% [markdown]
# <center>
#
# <img src="img/Qimage-7.JPG" width="600"/>
# </div>

# %% [markdown]
# <center>
#
# <img src="img/Qimage-8.JPG" width="350"/>
# </div>

# %% [markdown]
# Now, we would like to predict whether ornot a future **Dosage** will be effective.

# %% [markdown]
# NNs can fit a non-linear curve to the dataset!
#
# <center>
#
# <img src="img/Qimage-9.JPG" width="400"/>
# </div>

# %% [markdown]
# Assume that we have fit the NN (<font color='green'>green <font color='black'>curve) to this dataset!

# %% [markdown]
# <center>
#
# <img src="img/Qimage-11.JPG" width="750"/>
# </div>

# %% [markdown]
# <center>
#
# <img src="img/Qimage-12.JPG" width="750"/>
# </div>

# %% [markdown]
# The first thing we are going to do is plug the lowest **Dosage, 0**, into the **Neural Network**.
#
# <center>
#
# <img src="img/Qimage-13.JPG" width="950"/>
# </div>

# %% [markdown]
# To get from the **Input Node** to the top **Node** in the **Hidden Layer**:
#    * The connection multiplies the **Dosage** by **-34.4** and then add **2.14**.
#    * The result is an x-axis coordinate for the **Activation Function**.
#
# <center>
#
# <img src="img/Qimage-14.JPG" width="700"/>
# </div>
#
# $(\text{Dosage} \times -34.4) + 2.14 = \text{x-axis coordinate}$
#
# $(0 \times -34.4) + 2.14 = 2.14$

# %% [markdown]
# $f(\text{x-axis coordinate}) = log(1 + e^{\text{x-axis coordinate}}) = \text{y-axis coordinate}$
#
# $f(\text{2.14}) = log(1 + e^{2.14}) = 2.25$

# %% [markdown]
# If we increase the **Dosage** a litle bit and put **0.1** into the input:
#
#
# <img src="img/Qimage-15.JPG" width="700"/>
#
#
# $(\text{Dosage} \times -34.4) + 2.14 = \text{x-axis coordinate}$
#
# $(0.1 \times -34.4) + 2.14 = -1.3$
#
# $f(\text{x-axis coordinate}) = log(1 + e^{\text{x-axis coordinate}}) = \text{y-axis coordinate}$
#
# $f(\text{-1.3}) = log(1 + e^{-1.3}) = 0.24$

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-16.JPG" width="300"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-17.JPG" width="305"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>

# %% [markdown]
# **NOTE**: The full range of **Dosage** values, from **0** to **1**, corresponds to this relatively narrow range of values from the **Activation Function**.
#
# <center>
# <img src="img/Qimage-18.JPG" width="800"/>

# %% [markdown]
# * Now, we scale the y-axis values for the <font color='blue'>**blue curve** <font color='black'> by **-1.30**.
# * For example, when **Dosage = 0**, the current y-axis coordinate for the <font color='blue'>**blue curve** <font color='black'> is **2.25**.
# * So, we multiply **2.25** by **-1.3** and get **-2.93**.
# <center>
# <img src="img/Qimage-19.JPG" width="750"/>

# %% [markdown]
# Likewise, we multiply all of the other y-axis coordinates on the **blue curve** by **-1.3** and we end up with a NEW <font color='blue'>**blue curve** <font color='black'>.
#
# <center>
# <img src="img/Qimage-20.JPG" width="200"/>

# %% [markdown]
# * Now let's focus on the connection from the **Input Node**.
#
# <center>
# <img src="img/Qimage-21.JPG" width="800"/>
#
# $\text{x-axis coordinate} = (\text{Dosage} \times -2.52) + 1.29$
#
# $\text{x-axis coordinate} = (0 \times -2.52) + 1.29 = 1.29$
#
# $f(\text{x-axis coordinate}) = log(1 + e^{\text{x-axis coordinate}})$
#
# $f(\text{1.29}) = log(1 + e^{\text{1.29}}) = 1.53$

# %% [markdown]
# Now just plug in **Dosage** values form **0** to **1** to get the corresponding y-axis values.
#
# <center>
# <img src="img/Qimage-22.JPG" width="200"/>

# %% [markdown]
# <center>
# <img src="img/Qimage-23.JPG" width="800"/>

# %% [markdown]
# * Now the **Neural Network** tells us to add the y-axis coordinates from <font color='blue'>**blue curve** <font color='black'> to the <font color='orange'>**orange curve** <font color='black'>.
# * That gives us the <font color='green'>**green curve** <font color='black'>.
#
# <center>
# <img src="img/Qimage-24.JPG" width="800"/>

# %% [markdown]
# Finally, we subtract **0.58** from the y-axis values on the <font color='green'>**green curve** <font color='black'>.
# <center>
# <img src="img/Qimage-25.JPG" width="300"/>

# %% [markdown]
# In theory, **Neural Networks** can fit a <font color='green'>**green curve** <font color='black'> to just almost any dataset, no matter how complicated!
# <center>
# <img src="img/Qimage-26.JPG" width="1000"/>

# %% [markdown]
# # How much complexity do you think we should aim for modelling our NN?

# %% [markdown]
# <font size="25"><center>Backpropagation

# %% [markdown]
# ## Main Ideas of Backpropagation
#
# 1. Using the **Chain Rule** to calculate derivatives.
# 2. Plugging the derivatives into **Gradient Descent** to optimize parameters.

# %% [markdown]
# In the next following slides, we will talk about how the **Chain Rule** and **Gradient Descent** apply to multiple parameters simultaneously, and introduce some fancy notations!
#
# <center>
# <img src="img/Qimage-27.JPG" width="800"/>
#
# **NOTE**: **Back propagation** start with the last parameters (**$b_3$**) and works backwards to estimate all of the other parameters.

# %% [markdown]
# To start from the back, let's assume that we already have <font color='green'>optimal values<font color='black'> for all of the parameters except for the last **Bias** term (**$b_3$**).
#
# <center>
# <img src="img/Qimage-28.JPG" width="1000"/>

# %% [markdown]
# <center>
# <img src="img/Qimage-29.JPG" width="800"/>

# %% [markdown]
# <center>
# <img src="img/Qimage-30.JPG" width="800"/>
#
# * We don't know yet the optimal value for **$b_3$**, we have to give it an initial value.
# * Because **Bias** terms are usually initialized to **0**, we will set **$b_3=0$**.

# %% [markdown]
# We can quantify how good the <font color='green'>green curve<font color='black'> fits the data calculating the **Sum of the Squared Residulas**.
#
# <center>
# <img src="img/Qimage-31.JPG" width="200"/>
#
# $\text{SSR} = (0 - (-2.6))^2 + (1 - (-1.61))^2 + (0 - (-2.61))^2 = 20.4$

# %% [markdown]
# * When **$b_3 = 0$**, the **SSR = 20.4**.
# * If we increase **$b_3$** to **1**, then we would add **1** to the y-axis coordinates on the <font color='green'>**green curve** <font color='black'> and shift it up **1**.
#
# $\text{SSR} = (0 - (-1.61))^2 + (1 - (-0.61))^2 + (0 - (-1.61))^2 = 7.8$
#
# <center>
# <img src="img/Qimage-32.JPG" width="200"/>

# %% [markdown]
# If we increase $b_3$ again to **2** and **3**, we will get lower **SSR**.
#
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-33.JPG" width="230"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-34.JPG" width="305"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>

# %% [markdown]
# * If we had time to plug in tons of values for $b_3$, we would get this <font color='pink'>**pink curve** <font color='black'>.
# * So we could find the lowest point, which corresponds to the **$b_3$** that results in the lowest **SSR**.
# <center>
# <img src="img/Qimage-35.JPG" width="250"/>

# %% [markdown]
# * However, instead of plugging in tons of values o find the lowest point in the <font color='pink'>**pink curve** <font color='black'>, we use **Gradient Descent** to find it relatively quickly.
# <center>
# <img src="img/Qimage-36.JPG" width="220"/>
#
# * What doest that mean? (How to find the **Gradient Descent**?)

# %% [markdown]
# <center>
# <img src="img/Qimage-37.JPG" width="400"/>

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-38.JPG" width="190"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-28.JPG" width="605"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>
#
#
#
# $\text{Predicted}_i$ = <font color='green'> green curve <font color='black'>= <font color='blue'> blue <font color='black'>+ <font color='orange'> orange curve <font color='black'>+ $b_3$

# %% [markdown]
# We want to use **Gradient Descent** to optimize $b_3$ and that means we need to take the derivative of the **SSR** with respect to $b_3$ ($\frac{d\,SSR}{d\,b_3}$).
#
# <center>
# <img src="img/Qimage-39.JPG" width="200"/>

# %% [markdown]
# * And because the **SSR** are linked to $b_3$ by the **Predicted** values, we can use the **Chain Rule**!
#
# $\text{SSR} = \sum_{i=1}^{n=3}(\text{Observed}_i - \text{Predicted}_i)^2$
#
# $\text{Predicted}_i$ = <font color='green'> green curve <font color='black'>= <font color='blue'> blue <font color='black'>+ <font color='orange'> orange curve <font color='black'>+ $b_3$

# %% [markdown]
# $\frac{d\,SSR}{d\,b_3} = \frac{d\,SSR}{d\,Predicted} \times \frac{d\,Predicted}{d\,b_3}$

# %% [markdown]
# 1) $\text{SSR} = \sum_{i=1}^{n=3}(\text{Observed}_i - \text{Predicted}_i)^2$
#
# 2) $\text{Predicted}_i$ = <font color='green'> green curve <font color='black'>= <font color='blue'> blue <font color='black'>+ <font color='orange'> orange curve <font color='black'>+ $b_3$
#
# 3) $\frac{d\,SSR}{d\,b_3} = \frac{d\,SSR}{d\,Predicted} \times \frac{d\,Predicted}{d\,b_3}$

# %% [markdown]
# $\frac{d\,SSR}{d\,Predicted} = \frac{d\,}{d\,Predicted} \sum_{i=1}^{n=3}(\text{Observed}_i - \text{Predicted}_i)^2 \\ \quad\quad\quad=\sum_{i=1}^{n=3}2\times(\text{Observed}_i - \text{Predicted}_i) \times \frac{d\,}{d\,Predicted}(\text{Observed - Predicted}) \\  \quad\quad\quad=\sum_{i=1}^{n=3}2\times(\text{Observed}_i - \text{Predicted}_i) \times -1 \\  \quad\quad\quad=\sum_{i=1}^{n=3}-2\times(\text{Observed}_i - \text{Predicted}_i)$

# %% [markdown]
# $\frac{d\,Predicted}{d\,b_3} = \frac{d\,}{d\,b_3} (\text{green curve}) = \frac{d\,}{d\,b_3} (\text{blue + orange} + b_3) = \frac{d\,blue}{d\,b_3} + \frac{d\,orange}{d\,b_3} + \frac{d\,b_3}{d\,b_3} = 0 + 0 + 1 = 1$

# %% [markdown]
# $\frac{d\,SSR}{d\,b_3} = \sum_{i=1}^{n=3}-2\times(\text{Observed}_i - \text{Predicted}_i) \times 1$

# %% [markdown]
# * So, we have the derivative of the **SSR** with respect to $b_3$.
#
# $\frac{d\,SSR}{d\,b_3} = \frac{d\,SSR}{d\,Predicted} \times \frac{d\,Predicted}{d\,b_3} = \sum_{i=1}^{n=3}-2\times(\text{Observed}_i - \text{Predicted}_i) \times 1$

# %% [markdown]
# * This means we can plug this derivative into **Gradient Descent** to find the optimal value for $b_3$.
#
# $\frac{d\,SSR}{d\,b_3} = -2 \times (\text{Observed}_1 - \text{Predicted}_1) \times 1\\ \quad\quad\quad + -2 \times (\text{Observed}_2 - \text{Predicted}_2) \times 1\\\quad\quad\quad + -2 \times (\text{Observed}_3 - \text{Predicted}_3) \times 1$

# %% [markdown]
# $\frac{d\,SSR}{d\,b_3} =-2 \times (0 - \text{Predicted}_1) \times 1\\ \quad\quad\quad + -2 \times (1 - \text{Predicted}_2) \times 1\\\quad\quad\quad + -2 \times (0 - \text{Predicted}_3) \times 1$

# %% [markdown]
# * How about the **Predicted** values?

# %% [markdown]
# * The values **Predicted** are given by the <font color='green'>**green curve** <font color='black'>.
# * And, we get the **predicted** values on the <font color='green'>**green curve** <font color='black'>by running the **Dosages** through the **Neural Network**.
#
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-40.JPG" width="200"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-41.JPG" width="650"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>
#
# $\frac{d\,SSR}{d\,b_3} =-2 \times (0 - -2.6) \times 1\\ \quad\quad\quad + -2 \times (0 - -1.6) \times 1\\\quad\quad\quad + -2 \times (0 - -2.61) \times 1 = -15.7$

# %% [markdown]
# * This corresponds to the slope for when **$b_3 = 0$**.
#
# <center>
# <img src="img/Qimage-42.JPG" width="200"/>

# %% [markdown]
# * Now we put the slope ($\frac{d\,SSR}{d\,b_3}$) into the **Gradient Descent** equation.
# * We will set the **Learning Rate** to **0.1**.
#
# **Step Size** = **Slope** $\times$ **Learning Rate** = -15.7 $\times$ 0.1 = -1.57

# %% [markdown]
# * Now we use the **Step Size** to calculate the new value for $b_3$:
#
# **New $b_3$** = **Old $b_3$** - **Step Size** = 0 - (-1.57) = 1.57

# %% [markdown]
# * Changing $b_3$ to **1.57** shifts the <font color='green'>**green curve** <font color='black'> up.
# * This shrinks the **Residuals**.
#
# <center>
# <img src="img/Qimage-43.JPG" width="700"/>

# %% [markdown]
# * Now the new **Predicted** values give us:
#
#
# <div>
#
# <table><tr>
# <td>
#
# $\frac{d\,SSR}{d\,b_3} =-2 \times (0 - (-1.03)) \times 1\\ \quad\quad\quad + -2 \times (1 - (-0.03)) \times 1\\\quad\quad\quad + -2 \times (0 - (-1.04)) \times 1 = -6.26$
#
# </td>
# <td>
#
# <img src="img/Qimage-44.JPG" width="200"/>
#
# </td>
# </tr></table>
#
# <div>
#
#
#
# * This corresponds to the slope for when **$b_3 = 1.57$**

# %% [markdown]
# **Step Size** = **Slope** $\times$ **Learning Rate** = -6.26 $\times$ 0.1 = -0.626
#
# **New $b_3$** = **Old $b_3$** - **Step Size** = **1.57** - (-0.626) = 2.19

# %% [markdown]
# * Changing **b_3** to **2.19** shifts the <font color='green'>**green curve** <font color='black'> up further.
# * That also shrinks the **Residuals** even more.
#
# <center>
# <img src="img/Qimage-45.JPG" width="200"/>

# %% [markdown]
# We just keep taking steps until the **Step Size** is close to zero.
#
# **Step Size** = **Slope** $\times$ **Learning Rate** = close to 0 $\times$ 0.1 = close to 0
#
# **New $b_3$** = **Old $b_3$** - **Step Size** = **2.61** - close to 0 = 2.61
#
# <div>
#
# <table><tr>
# <td>
#
# <img src="img/Qimage-46.JPG" width="200"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-47.JPG" width="630"/>
#
# </td>
#
# <td>
#
# <img src="img/Qimage-48.JPG" width="250"/>
#
# </td>
# </tr></table>
#
# <div>

# %% [markdown]
# In conclusion, **Main Idea** for **Backpropagation** is that when a parameter like $b_3$ is unknown:
#
# * We use the **Chain Rule** to calculate the derivative of the **Sum of the Squared Residulas (SSR)**
#
#     * with respect to the unknown parameters (in this case $b_3$).
#
# * Then we initialize the unknown parameters with a number (in this case we set $b_3 = 0$)
#
# * And used **Gradient Descent** to optimize the unknown parameter

# %% [markdown]
# # Let's Get Outside The Neural Networks!

# %% [markdown]
# * Non-linear models for classification and regression
# * Work well for very large datasets
# * Slow to train – need for GPUs
# * Require preprocessing → similar to SVM or linear models, unlike trees
# * MANY variants
#     * Convolutional Neural Networks
#     * Long-Short Term Memory
#     * Generative Adverserial Networks
#     * Deep Reinforcement Learning
#     * Autoencoders

# %% [markdown]
# # Picking Optimization Algorithms

# %% [markdown]
# * **Small dataset**: off the shelf like lbfgs
# * **Big dataset**: ADAptive Moment estimation (Adam) / Root Mean Square Propagation (RMSprop)

# %% [markdown]
# Are you interested in diving deep into the neural networks optimization?
#
# Chapter 8 of Deep Learning book by Goodfellow et al. is your food!
#
# https://www.deeplearningbook.org/

# %% [markdown]
# # Neural Nets in Practice

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(precision=3, suppress=True)
from sklearn.model_selection import train_test_split

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=100, noise=0.25, random_state=2)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
xlim = plt.xlim()
ylim = plt.ylim()

# %%
mlp = MLPClassifier(solver='lbfgs', random_state=0).fit(X_train, y_train)
print(mlp.score(X_train, y_train))
print(mlp.score(X_test, y_test))
# Out:
# 1.0
# 0.84

# %%
xs = np.linspace(xlim[0], xlim[1], 1000)
ys = np.linspace(ylim[0], ylim[1], 1000)
xx, yy = np.meshgrid(xs, ys)
X_grid = np.c_[xx.ravel(), yy.ravel()]
plt.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)

plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-0.9671217878433745, 1.3766745187608307)

# %% [markdown]
# # Random State

# %%
import warnings
warnings.filterwarnings(action='ignore')
                        
fig, axes = plt.subplots(3, 3, figsize=(15, 10))
for ax, i in zip(axes.ravel(), range(10)):
    mlp = MLPClassifier(solver='lbfgs', random_state=i).fit(X_train, y_train)

    ax.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train)

    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.set_xticks(())
    ax.set_yticks(())

# %% [markdown]
# # Hidden Layer Size

# %%
mlp = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(5,), random_state=0)
mlp.fit(X_train, y_train)
print(mlp.score(X_train, y_train))
print(mlp.score(X_test, y_test))
# Out:
# 0.9733333333333334
# 0.84

# %%
plt.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)

plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-0.9671217878433745, 1.3766745187608307)

# %%
mlp = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(10, 10, 10), random_state=0)
mlp.fit(X_train, y_train)
print(mlp.score(X_train, y_train))
print(mlp.score(X_test, y_test))
# Out:
# 0.9733333333333334
# 0.92

# %%
plt.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-0.9671217878433745, 1.3766745187608307)

# %% [markdown]
# # Activation Functions

# %%
mlp = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(10, 10, 10), activation="tanh", random_state=0)
mlp.fit(X_train, y_train)
print(mlp.score(X_train, y_train))
print(mlp.score(X_test, y_test))
# Out:
# 1.0
# 0.84

# %%
plt.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-0.9671217878433745, 1.3766745187608307)

# %% [markdown]
# # Neural Networks for Regression

# %%
rng = np.random.RandomState(0)
x = np.sort(rng.uniform(size=100))
y = np.sin(10 * x) + 5 * x + np.random.normal(0, .3, size=100)
plt.plot(x, y, 'o')

# %%
from sklearn.neural_network import MLPRegressor
X = x.reshape(-1, 1)
mlp_relu = MLPRegressor(solver="lbfgs").fit(X, y)
mlp_tanh = MLPRegressor(solver="lbfgs", activation='tanh').fit(X, y)

# %%
line = np.linspace(0, 1, 100)
plt.plot(x, y, 'o')
plt.plot(line, mlp_relu.predict(line.reshape(-1, 1)), label="relu")
plt.plot(line, mlp_tanh.predict(line.reshape(-1, 1)), label="tanh")
plt.legend()

# %% [markdown]
# # Complexity Control

# %% [markdown]
# * Number of parameters
# * Regularization
# * Early Stopping
# * (drop-out)

# %% [markdown]
# # Grid-Searching Neural Nets

# %% [markdown]
# ### 1. Searching L2 Regularization

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, stratify=data.target, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
pipe = make_pipeline(StandardScaler(), MLPClassifier(solver="lbfgs", random_state=1))
param_grid = {'mlpclassifier__alpha': np.logspace(-3, 3, 7)}
grid = GridSearchCV(pipe, param_grid, cv=5, return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('mlpclassifier',
#                                         MLPClassifier(random_state=1,
#                                                       solver='lbfgs'))]),
#              param_grid={'mlpclassifier__alpha': array([   0.001,    0.01 ,    0.1  ,    1.   ,   10.   ,  100.   ,
#        1000.   ])},
#              return_train_score=True)

# %%
results = pd.DataFrame(grid.cv_results_)
res = results.pivot_table(index="param_mlpclassifier__alpha", 
                          values=["mean_test_score", "mean_train_score", "std_test_score", "std_train_score"])
res
# Out:
#                             mean_test_score  mean_train_score  std_test_score  \
# param_mlpclassifier__alpha
# 0.001                              0.981231          1.000000        0.005720
# 0.010                              0.981231          1.000000        0.005720
# 0.100                              0.976553          1.000000        0.012813
# 1.000                              0.978878          0.998825        0.011516
# 10.000                             0.983611          0.990611        0.011869
# 100.000                            0.939097          0.946598        0.033973
# 1000.000                           0.626758          0.626760        0.004593
#
#                             std_train_score
# param_mlpclassifier__alpha
# 0.001                              0.000000
# 0.010                              0.000000
# 0.100                              0.000000
# 1.000                              0.001439
# 10.000                             0.002193
# 100.000                            0.002148
# 1000.000                           0.001145

# %%
res.mean_test_score.plot(yerr=res.std_test_score)
res.mean_train_score.plot(yerr=res.std_train_score)
plt.xscale("log")
plt.ylim(0.95, 1.01)
plt.legend()

# %% [markdown]
# ### 2. Searching Hidden Layer Sizes

# %%
from sklearn.model_selection import GridSearchCV
pipe = make_pipeline(StandardScaler(), MLPClassifier(solver="lbfgs", random_state=1))

# Now it is your turn to grid search the Hidden Layer Sizes:
# You should search one and two hidden layers with sizes of (10,), (50,), (100,), (500,), (10, 10), (50, 50), (100, 100), (500, 500)
# Name the GridSearchCV object as "grid" and fit it on X_train and y_train as below:

grid.fit(X_train, y_train)

# %%
results = pd.DataFrame(grid.cv_results_)
res = results.pivot_table(index="param_mlpclassifier__hidden_layer_sizes", 
                          values=["mean_test_score", "mean_train_score", "std_test_score", "std_train_score"])
res
# Out:
#                                          mean_test_score  mean_train_score  \
# param_mlpclassifier__hidden_layer_sizes
# (10,)                                           0.967168               1.0
# (10, 10)                                        0.957756               1.0
# (50,)                                           0.978878               1.0
# (50, 50)                                        0.974200               1.0
# (100,)                                          0.981231               1.0
# (100, 100)                                      0.974200               1.0
# (500,)                                          0.971847               1.0
# (500, 500)                                      0.976525               1.0
#
#                                          std_test_score  std_train_score
# param_mlpclassifier__hidden_layer_sizes
# (10,)                                          0.017202              0.0
# (10, 10)                                       0.005678              0.0
# (50,)                                          0.011516              0.0
# (50, 50)                                       0.015559              0.0
# (100,)                                         0.005720              0.0
# (100, 100)                                     0.008717              0.0
# (500,)                                         0.011950              0.0
# (500, 500)                                     0.007441              0.0

# %%
res.mean_test_score.plot(yerr=res.std_test_score)
res.mean_train_score.plot(yerr=res.std_train_score)
plt.legend()

# %% [markdown]
# # Introduction to Keras

# %% [markdown]
# ### 1. Preparing data

# %%
df = pd.read_csv('diabetes.csv')
print('Shape of the data frame: {}'.format(df.shape))
df.head(3)
# Out:
# Shape of the data frame: (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
X = df.iloc[:,0:8]
y = df.iloc[:, 8]
print(X.dtypes)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [markdown]
# ### 2. Keras Sequential
#
# * It uses TensorFlow backend.
# * Install them as:
#     * ``!pip install tensorflow``
#     * ``!pip install keras``

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Input

model = Sequential([
    Dense(4, input_shape=(X_train.shape[1],), name='dense_1'),
    Activation('relu', name='activation_1'),
    Dense(1, name='dense_2'),
    Activation('sigmoid', name='activation_2')])

# %%
# !pip install tensorflow
# !pip install keras

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# activation_1 (Activation)    (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2. Setting Optimizer

# %% [markdown]
# <center>
# <img src="img/Qimage-49.JPG" width="1000"/>

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# https://keras.io/api/models/model_training_apis/

# %% [markdown]
# ### 3. Fit Model

# %%
history_callback = model.fit(X_train, y_train, batch_size=10, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 1s 2ms/step - loss: 1.0241 - accuracy: 0.3351
# Epoch 2/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.9022 - accuracy: 0.3829
# Epoch 3/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.7931 - accuracy: 0.4418
# Epoch 4/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.7200 - accuracy: 0.5263
# Epoch 5/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.5767
# Epoch 6/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.6387 - accuracy: 0.6536
# Epoch 7/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.6079 - accuracy: 0.7258
# Epoch 8/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.6184 - accuracy: 0.7460
# Epoch 9/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.5877 - accuracy: 0.7639
# Epoch 10/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.5767 - accuracy: 0.7365
# Epoch 11/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.7133
# Epoch 12/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.5326 - accuracy: 0.7639
# Epoch 13/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4936 - accuracy: 0.7907
# Epoch 14/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7751
# Epoch 15/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4949 - accuracy: 0.7855
# Epoch 16/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4996 - accuracy: 0.7657
# Epoch 17/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.5003 - accuracy: 0.7767
# Epoch 18/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4857 - accuracy: 0.7813
# Epoch 19/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4654 - accuracy: 0.7829
# Epoch 20/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4521 - accuracy: 0.7902
# Epoch 21/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.7837
# Epoch 22/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.7874
# Epoch 23/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4738 - accuracy: 0.7996
# Epoch 24/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4621 - accuracy: 0.7921
# Epoch 25/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4588 - accuracy: 0.7961
# Epoch 26/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4410 - accuracy: 0.8018
# Epoch 27/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.7710: 0s - loss: 0.4865 - accuracy: 0.76
# Epoch 28/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.7891
# Epoch 29/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4779 - accuracy: 0.7758
# Epoch 30/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4440 - accuracy: 0.7950
# Epoch 31/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4638 - accuracy: 0.7849
# Epoch 32/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.7875
# Epoch 33/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4653 - accuracy: 0.7762
# Epoch 34/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.7622
# Epoch 35/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4693 - accuracy: 0.7850
# Epoch 36/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.7850
# Epoch 37/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.8044
# Epoch 38/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4653 - accuracy: 0.7835
# Epoch 39/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4672 - accuracy: 0.7646
# Epoch 40/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.7986
# Epoch 41/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4669 - accuracy: 0.7837
# Epoch 42/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.7873
# Epoch 43/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4125 - accuracy: 0.8223
# Epoch 44/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.3978 - accuracy: 0.8131
# Epoch 45/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4713 - accuracy: 0.7759
# Epoch 46/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4640 - accuracy: 0.7757
# Epoch 47/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4431 - accuracy: 0.7940
# Epoch 48/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4445 - accuracy: 0.7871
# Epoch 49/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.8012
# Epoch 50/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4400 - accuracy: 0.7857
# Epoch 51/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.7881
# Epoch 52/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4443 - accuracy: 0.7848
# Epoch 53/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.8085
# Epoch 54/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4540 - accuracy: 0.7824
# Epoch 55/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4349 - accuracy: 0.8036
# Epoch 56/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4599 - accuracy: 0.7769
# Epoch 57/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.8062
# Epoch 58/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.7848
# Epoch 59/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4516 - accuracy: 0.7987
# Epoch 60/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4584 - accuracy: 0.7781
# Epoch 61/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4535 - accuracy: 0.7941
# Epoch 62/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4424 - accuracy: 0.8139
# Epoch 63/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.7887
# Epoch 64/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4523 - accuracy: 0.8171
# Epoch 65/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.7986
# Epoch 66/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.8017
# Epoch 67/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7914
# Epoch 68/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4827 - accuracy: 0.7833
# Epoch 69/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4275 - accuracy: 0.8235
# Epoch 70/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4206 - accuracy: 0.8255
# Epoch 71/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8112
# Epoch 72/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4492 - accuracy: 0.7918
# Epoch 73/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4534 - accuracy: 0.7811
# Epoch 74/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4309 - accuracy: 0.8056
# Epoch 75/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4598 - accuracy: 0.7873
# Epoch 76/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.7938
# Epoch 77/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4330 - accuracy: 0.7947
# Epoch 78/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.7966
# Epoch 79/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8134
# Epoch 80/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.8024
# Epoch 81/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4406 - accuracy: 0.7949
# Epoch 82/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4572 - accuracy: 0.7691
# Epoch 83/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4766 - accuracy: 0.7851
# Epoch 84/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4109 - accuracy: 0.8224
# Epoch 85/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4514 - accuracy: 0.7780
# Epoch 86/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4470 - accuracy: 0.7837
# Epoch 87/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8216
# Epoch 88/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4364 - accuracy: 0.7982
# Epoch 89/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8272
# Epoch 90/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.8047
# Epoch 91/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4278 - accuracy: 0.8031
# Epoch 92/100
# 58/58 [==============================] - ETA: 0s - loss: 0.4252 - accuracy: 0.81 - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8090
# Epoch 93/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4459 - accuracy: 0.8001
# Epoch 94/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7996
# Epoch 95/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4570 - accuracy: 0.7803
# Epoch 96/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.7841
# Epoch 97/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.7984
# Epoch 98/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.8247
# Epoch 99/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4768 - accuracy: 0.7764
# Epoch 100/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4401 - accuracy: 0.7927

# %%
pd.DataFrame(history_callback.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4. Evaluating on Test Set

# %%
eval_tr = model.evaluate(X_train, y_train)
eval_tr
# Out:
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4320 - accuracy: 0.8021
# [0.43199682235717773, 0.8020833134651184]

# %%
eval_ts = model.evaluate(X_test, y_test)
eval_ts
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5393 - accuracy: 0.7344
# [0.5392690300941467, 0.734375]

# %% [markdown]
# ### 5. Wrappers for sklearn

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

def make_model(optimizer="adam", hidden_size=32):
    model = Sequential([
        Dense(4, input_shape=(X_train.shape[1],), name='dense_1'),
        Activation('relu', name='activation_1'),
        Dense(4, name='dense_2'),
        Activation('relu', name='activation_2'),
        Dense(1, name='dense_3'),
        Activation('sigmoid', name='activation_3')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

clf = KerasClassifier(make_model)
param_grid = {'epochs': [10, 50, 100],  
              'hidden_size': [(4,4), (4,16), (16,16)]}
grid = GridSearchCV(clf, param_grid=param_grid, cv=5, return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 2ms/step - loss: 0.7083 - accuracy: 0.6502
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.
100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.7925
# Epoch 67/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4321 - accuracy: 0.8075
# Epoch 68/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.7946
# Epoch 69/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.7883
# Epoch 70/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4151 - accuracy: 0.8013
# Epoch 71/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4454 - accuracy: 0.7831
# Epoch 72/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4606 - accuracy: 0.7852
# Epoch 73/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4665 - accuracy: 0.7732
# Epoch 74/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4142 - accuracy: 0.8296
# Epoch 75/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4661 - accuracy: 0.7827
# Epoch 76/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4622 - accuracy: 0.7802
# Epoch 77/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4443 - accuracy: 0.7876
# Epoch 78/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4441 - accuracy: 0.7904
# Epoch 79/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4194 - accuracy: 0.8214
# Epoch 80/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4685 - accuracy: 0.7796
# Epoch 81/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4369 - accuracy: 0.8115
# Epoch 82/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.8077
# Epoch 83/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4409 - accuracy: 0.7955
# Epoch 84/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.7792
# Epoch 85/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4209 - accuracy: 0.8102
# Epoch 86/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4549 - accuracy: 0.7854
# Epoch 87/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4070 - accuracy: 0.8048
# Epoch 88/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.8007
# Epoch 89/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.7832
# Epoch 90/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4479 - accuracy: 0.7985
# Epoch 91/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4446 - accuracy: 0.7907
# Epoch 92/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4311 - accuracy: 0.7948
# Epoch 93/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4228 - accuracy: 0.7998
# Epoch 94/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4436 - accuracy: 0.8030
# Epoch 95/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.8147
# Epoch 96/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4503 - accuracy: 0.7969
# Epoch 97/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4350 - accuracy: 0.7923
# Epoch 98/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4237 - accuracy: 0.7955
# Epoch 99/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4297 - accuracy: 0.8017
# Epoch 100/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.7765
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4632 - accuracy: 0.7826
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4356 - accuracy: 0.8004
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 0.7007 - accuracy: 0.5137
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6988 - accuracy: 0.5608
# Epoch 3/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6926 - accuracy: 0.6017
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.6287
# Epoch 5/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6667 - accuracy: 0.6426
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6546 - accuracy: 0.6482
# Epoch 7/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6393 - accuracy: 0.6698
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6323 - accuracy: 0.6430
# Epoch 9/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6265 - accuracy: 0.6333
# Epoch 10/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6189 - accuracy: 0.6389
# Epoch 11/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6037 - accuracy: 0.6497
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5875 - accuracy: 0.6478
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5907 - accuracy: 0.6400
# Epoch 14/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5632 - accuracy: 0.6522
# Epoch 15/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5768 - accuracy: 0.6399
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5402 - accuracy: 0.6701
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5885 - accuracy: 0.6389
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5503 - accuracy: 0.6895
# Epoch 19/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5644 - accuracy: 0.6818
# Epoch 20/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5663 - accuracy: 0.6819
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5587 - accuracy: 0.7052
# Epoch 22/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5270 - accuracy: 0.7202
# Epoch 23/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.7313
# Epoch 24/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5048 - accuracy: 0.7346
# Epoch 25/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5169 - accuracy: 0.7376
# Epoch 26/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5211 - accuracy: 0.7413
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5438 - accuracy: 0.7220
# Epoch 28/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5302 - accuracy: 0.7277
# Epoch 29/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.7537
# Epoch 30/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5028 - accuracy: 0.7585
# Epoch 31/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7173
# Epoch 32/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4980 - accuracy: 0.7499
# Epoch 33/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4791 - accuracy: 0.7492
# Epoch 34/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4839 - accuracy: 0.7554
# Epoch 35/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4791 - accuracy: 0.7596
# Epoch 36/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5030 - accuracy: 0.7450
# Epoch 37/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4637 - accuracy: 0.7512
# Epoch 38/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4960 - accuracy: 0.7445
# Epoch 39/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4679 - accuracy: 0.7785
# Epoch 40/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.7584
# Epoch 41/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4938 - accuracy: 0.7496
# Epoch 42/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4402 - accuracy: 0.7931
# Epoch 43/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4773 - accuracy: 0.7586
# Epoch 44/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.7891
# Epoch 45/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.7750
# Epoch 46/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4715 - accuracy: 0.7532
# Epoch 47/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4632 - accuracy: 0.7632
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4761 - accuracy: 0.7662
# Epoch 49/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4554 - accuracy: 0.7586
# Epoch 50/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7653
# Epoch 51/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7587
# Epoch 52/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4587 - accuracy: 0.7634
# Epoch 53/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4748 - accuracy: 0.7583
# Epoch 54/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4671 - accuracy: 0.7773
# Epoch 55/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.7777
# Epoch 56/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4563 - accuracy: 0.7697
# Epoch 57/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4420 - accuracy: 0.8040
# Epoch 58/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4577 - accuracy: 0.7665
# Epoch 59/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4720 - accuracy: 0.7718
# Epoch 60/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4698 - accuracy: 0.7615
# Epoch 61/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4284 - accuracy: 0.7917
# Epoch 62/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4430 - accuracy: 0.7851
# Epoch 63/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4542 - accuracy: 0.7542
# Epoch 64/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4471 - accuracy: 0.7862
# Epoch 65/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4363 - accuracy: 0.7992
# Epoch 66/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4445 - accuracy: 0.7740
# Epoch 67/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4222 - accuracy: 0.8006
# Epoch 68/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4449 - accuracy: 0.7873
# Epoch 69/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4459 - accuracy: 0.7618
# Epoch 70/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4450 - accuracy: 0.7828
# Epoch 71/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4435 - accuracy: 0.7730
# Epoch 72/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4574 - accuracy: 0.7777
# Epoch 73/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.8068
# Epoch 74/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.7842
# Epoch 75/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4593 - accuracy: 0.7713
# Epoch 76/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4506 - accuracy: 0.7800
# Epoch 77/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4324 - accuracy: 0.8143
# Epoch 78/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4568 - accuracy: 0.7827
# Epoch 79/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4260 - accuracy: 0.7968
# Epoch 80/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4444 - accuracy: 0.7930
# Epoch 81/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4442 - accuracy: 0.7902
# Epoch 82/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.7761
# Epoch 83/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4404 - accuracy: 0.7801
# Epoch 84/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4252 - accuracy: 0.8026
# Epoch 85/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4217 - accuracy: 0.8020
# Epoch 86/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4530 - accuracy: 0.7676
# Epoch 87/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4293 - accuracy: 0.7881
# Epoch 88/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4294 - accuracy: 0.7856
# Epoch 89/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4245 - accuracy: 0.8003
# Epoch 90/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4303 - accuracy: 0.8049
# Epoch 91/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4378 - accuracy: 0.7763
# Epoch 92/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.8101
# Epoch 93/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7970
# Epoch 94/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.8109
# Epoch 95/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4520 - accuracy: 0.7792
# Epoch 96/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4579 - accuracy: 0.7812
# Epoch 97/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4061 - accuracy: 0.8108
# Epoch 98/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4463 - accuracy: 0.7886
# Epoch 99/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.7984
# Epoch 100/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4403 - accuracy: 0.7893
# GridSearchCV(cv=5,
#              estimator=<tensorflow.python.keras.wrappers.scikit_learn.KerasClassifier object at 0x000001CF2DCF3E20>,
#              param_grid={'epochs': [10, 50, 100],
#                          'hidden_size': [(4, 4), (4, 16), (16, 16)]},
#              return_train_score=True)

# %%
res = pd.DataFrame(grid.cv_results_)
res.pivot_table(index=["param_epochs", "param_hidden_size"],
                values=['mean_train_score', "mean_test_score"])
# Out:
#                                 mean_test_score  mean_train_score
# param_epochs param_hidden_size
# 10           (4, 4)                    0.647661          0.654970
#              (4, 16)                   0.654513          0.658008
#              (16, 16)                  0.663208          0.670140
# 50           (4, 4)                    0.741454          0.774293
#              (4, 16)                   0.717061          0.760871
#              (16, 16)                  0.763973          0.770409
# 100          (4, 4)                    0.779610          0.797754
#              (4, 16)                   0.765727          0.786038
#              (16, 16)                  0.760540          0.806435

# %% [markdown]
# ### 6. Drop-out Regularization

# %% [markdown]
# <center>
# <img src="img/Qimage-51.JPG" width="700"/>

# %% [markdown]
# * https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
# * Rate often as high as .5, i.e. 50% of units set to zero!
# * Avoid overfitting

# %% [markdown]
# # It Is Your Turn
#
# Please implment two ``Dense`` layers in the above network.
#
# * You should add two ``Dropout`` layers after the ``Activation`` layers.
# * The dropout rate should be set as 0.5.
# * Please change the number of hidden neurons in the two ``Dense`` layers to 128 and 64, respectively.

# %%
# YOUR CODE HERE
predictions = model.predict(X_test)

# %% [markdown]
# <font size="25"><center>Thank you!
